# %%
import os
import numpy as np
import pickle as pkl
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# # Data Split: Test

# %%
test_adult = open('SGNet_PIE_test_adult.pkl', 'rb')
test_adult = pkl.load(test_adult)
test_child = open('SGNet_PIE_test_child.pkl', 'rb')
test_child = pkl.load(test_child)
test_elderly = open('SGNet_PIE_test_elderly.pkl', 'rb')
test_elderly = pkl.load(test_elderly)
test_all = open('SGNet_PIE_test_all.pkl', 'rb')
test_all = pkl.load(test_all)

# %% [markdown]
# ## Statistics

# %% [markdown]
# #### Number of trajectories

# %%
print('Child:', str(len(test_child['MSE']['ADE_05'])))
print('Adult:', str(len(test_adult['MSE']['ADE_05'])))
print('Elderly:', str(len(test_elderly['MSE']['ADE_05'])))
print('All:', str(len(test_all['MSE']['ADE_05'])))
# Out:
# Child: 96
# Adult: 33218
# Elderly: 2894
# All: 36208

# %% [markdown]
# #### Mean

# %%
mean_data = {'child': test_child['MEAN'], 'adult': test_adult['MEAN'], 'elderly': test_elderly['MEAN'], 'all': test_all['MEAN']}
pd.DataFrame.from_dict(mean_data, orient='index')
# Out:
#               ADE_05       ADE_10       ADE_15         CADE         CFADE
# child    2594.326233  4185.970912  7095.978055  6760.429646  17227.567856
# adult    2727.304584  4013.193323  6517.124339  6141.784049  15597.605953
# elderly  2859.140037  4455.724895  7375.801219  6967.766018  17664.600849
# all      2737.489236  4049.021677  6587.290624  6209.442627  15767.136432

# %% [markdown]
# #### SD

# %%
SD_data = {'child': test_child['SD'], 'adult': test_adult['SD'], 'elderly': test_elderly['SD'], 'all': test_all['SD']}
pd.DataFrame.from_dict(SD_data, orient='index')
# Out:
#               ADE_05       ADE_10        ADE_15          CADE         CFADE
# child     847.448364  1652.942871   5031.293457   4993.521484  19101.027344
# adult    1859.942383  5405.446777  11833.785156  11773.638672  37063.566406
# elderly  1935.926270  5058.221680  10430.435547  10351.705078  31615.253906
# all      1864.538208  5373.330566  11717.163086  11655.624023  36625.750000

# %% [markdown]
# ## Example Histogram

# %%
fig, ax = plt.subplots(figsize = (10, 10))
count, edges, bars = ax.hist(test_child['MSE']['ADE_05'], bins = 50);
ax.set_xlabel('MSE')
ax.set_ylabel('# of trajectories')
plt.bar_label(bars);

# %%
fig, ax = plt.subplots(figsize = (10, 10))
count, edges, bars = ax.hist(test_adult['MSE']['ADE_05'], bins = 50);
ax.set_xlabel('MSE')
ax.set_ylabel('# of trajectories')
plt.bar_label(bars);
# Out:
# 2727.3044

# %% [markdown]
# ## Box Plots - Test Split

# %% [markdown]
# #### ADE(0.5)

# %%
fig, ax = plt.subplots(figsize = (10, 10))
data = [test_child['MSE']['ADE_05'], test_adult['MSE']['ADE_05'], test_elderly['MSE']['ADE_05'], test_all['MSE']['ADE_05']]
ax.boxplot(data);
ax.set_title('ADE(0.5) With Outliers');
ax.set_ylabel('MSE');
plt.xticks([1, 2, 3, 4], ['child', 'adult', 'elderly', 'all']);

fig, ax = plt.subplots(figsize = (10, 10))
ax.boxplot(data, showfliers = False);
ax.set_title('ADE(0.5) No Outliers');
ax.set_ylabel('MSE');
plt.xticks([1, 2, 3, 4], ['child', 'adult', 'elderly', 'all']);

# %% [markdown]
# #### ADE(1.0)

# %%
fig, ax = plt.subplots(figsize = (10, 10))
data = [test_child['MSE']['ADE_10'], test_adult['MSE']['ADE_10'], test_elderly['MSE']['ADE_10'], test_all['MSE']['ADE_10']]
ax.boxplot(data);
ax.set_title('ADE(1.0) With Outliers');
ax.set_ylabel('MSE');
plt.xticks([1, 2, 3, 4], ['child', 'adult', 'elderly', 'all']);

fig, ax = plt.subplots(figsize = (10, 10))
ax.boxplot(data, showfliers = False);
ax.set_title('ADE(1.0) No Outliers');
ax.set_ylabel('MSE');
plt.xticks([1, 2, 3, 4], ['child', 'adult', 'elderly', 'all']);

# %% [markdown]
# #### ADE(1.5)

# %%
fig, ax = plt.subplots(figsize = (10, 10))
data = [test_child['MSE']['ADE_15'], test_adult['MSE']['ADE_15'], test_elderly['MSE']['ADE_15'], test_all['MSE']['ADE_15']]
ax.boxplot(data);
ax.set_title('ADE(1.5) With Outliers');
ax.set_ylabel('MSE');
plt.xticks([1, 2, 3, 4], ['child', 'adult', 'elderly', 'all']);

fig, ax = plt.subplots(figsize = (10, 10))
ax.boxplot(data, showfliers = False);
ax.set_title('ADE(1.5) No Outliers');
ax.set_ylabel('MSE');
plt.xticks([1, 2, 3, 4], ['child', 'adult', 'elderly', 'all']);

# %% [markdown]
# #### C-ADE(1.5)

# %%
fig, ax = plt.subplots(figsize = (10, 10))
data = [test_child['MSE']['CADE'], test_adult['MSE']['CADE'], test_elderly['MSE']['CADE'], test_all['MSE']['CADE']]
ax.boxplot(data);
ax.set_title('C-ADE(1.5) With Outliers');
ax.set_ylabel('MSE');
plt.xticks([1, 2, 3, 4], ['child', 'adult', 'elderly', 'all']);

fig, ax = plt.subplots(figsize = (10, 10))
ax.boxplot(data, showfliers = False);
ax.set_title('C-ADE(1.5) No Outliers');
ax.set_ylabel('MSE');
plt.xticks([1, 2, 3, 4], ['child', 'adult', 'elderly', 'all']);

# %% [markdown]
# #### C-FDE(1.5)

# %%
fig, ax = plt.subplots(figsize = (10, 10))
data = [test_child['MSE']['CFADE'], test_adult['MSE']['CFADE'], test_elderly['MSE']['CFADE'], test_all['MSE']['CFADE']]
ax.boxplot(data);
ax.set_title('C-FDE(1.5) With Outliers');
ax.set_ylabel('MSE');
plt.xticks([1, 2, 3, 4], ['child', 'adult', 'elderly', 'all']);

fig, ax = plt.subplots(figsize = (10, 10))
ax.boxplot(data, showfliers = False);
ax.set_title('C-FDE(1.5) No Outliers');
ax.set_ylabel('MSE');
plt.xticks([1, 2, 3, 4], ['child', 'adult', 'elderly', 'all']);

# %% [markdown]
# # Data Split: Train

# %%
train_adult = open('SGNet_PIE_train_adult.pkl', 'rb')
train_adult = pkl.load(train_adult)
train_child = open('SGNet_PIE_train_child.pkl', 'rb')
train_child = pkl.load(train_child)
train_elderly = open('SGNet_PIE_train_elderly.pkl', 'rb')
train_elderly = pkl.load(train_elderly)
train_all = open('SGNet_PIE_train_all.pkl', 'rb')
train_all = pkl.load(train_all)

# %% [markdown]
# ## Statistics

# %% [markdown]
# #### Number of trajectories

# %%
print('Child:', str(len(train_child['MSE']['ADE_05'])))
print('Adult:', str(len(train_adult['MSE']['ADE_05'])))
print('Elderly:', str(len(train_elderly['MSE']['ADE_05'])))
print('All:', str(len(train_all['MSE']['ADE_05'])))
# Out:
# Child: 663
# Adult: 39860
# Elderly: 3960
# All: 44483

# %% [markdown]
# #### Mean

# %%
mean_data = {'child': train_child['MEAN'], 'adult': train_adult['MEAN'], 'elderly': train_elderly['MEAN'], 'all': train_all['MEAN']}
pd.DataFrame.from_dict(mean_data, orient='index')
# Out:
#               ADE_05       ADE_10       ADE_15         CADE         CFADE
# child    2823.112990  4626.414447  8145.248410  7808.060808  21247.402555
# adult    2660.516945  4005.985777  6742.675736  6375.955283  16798.630013
# elderly  2870.691925  4541.945006  7875.191484  7492.603698  20276.301104
# all      2681.650729  4062.945577  6864.400171  6496.707338  17174.528979

# %% [markdown]
# #### SD

# %%
SD_data = {'child': train_child['SD'], 'adult': train_adult['SD'], 'elderly': train_elderly['SD'], 'all': train_all['SD']}
pd.DataFrame.from_dict(SD_data, orient='index')
# Out:
#               ADE_05       ADE_10        ADE_15          CADE         CFADE
# child    2202.019287  6411.420410  13950.174805  13943.944336  43899.078125
# adult    1974.091797  5889.238770  13246.267578  13184.104492  41993.769531
# elderly  2068.880859  5706.992676  12421.008789  12317.003906  40111.644531
# all      1987.264771  5883.773438  13190.600586  13125.790039  41873.488281

# %% [markdown]
# ## Box Plots - Train Split

# %% [markdown]
# #### ADE(0.5)

# %%
fig, ax = plt.subplots(figsize = (10, 10))
data = [test_child['MSE']['ADE_05'], test_adult['MSE']['ADE_05'], test_elderly['MSE']['ADE_05'], test_all['MSE']['ADE_05']]
ax.boxplot(data);
ax.set_title('ADE(0.5) With Outliers');
ax.set_ylabel('MSE');
plt.xticks([1, 2, 3, 4], ['child', 'adult', 'elderly', 'all']);

fig, ax = plt.subplots(figsize = (10, 10))

ax.boxplot(data, showfliers = False);
ax.set_title('ADE(0.5) No Outliers');
ax.set_ylabel('MSE');
plt.xticks([1, 2, 3, 4], ['child', 'adult', 'elderly', 'all']);

# %% [markdown]
# #### ADE(1.0)

# %%
fig, ax = plt.subplots(figsize = (10, 10))
data = [test_child['MSE']['ADE_10'], test_adult['MSE']['ADE_10'], test_elderly['MSE']['ADE_10'], test_all['MSE']['ADE_10']]
ax.boxplot(data);
ax.set_title('ADE(1.0) With Outliers');
ax.set_ylabel('MSE');
plt.xticks([1, 2, 3, 4], ['child', 'adult', 'elderly', 'all']);

fig, ax = plt.subplots(figsize = (10, 10))

ax.boxplot(data, showfliers = False);
ax.set_title('ADE(1.0) No Outliers');
ax.set_ylabel('MSE');
plt.xticks([1, 2, 3, 4], ['child', 'adult', 'elderly', 'all']);

# %% [markdown]
# #### ADE(1.5)

# %%
fig, ax = plt.subplots(figsize = (10, 10))
data = [train_child['MSE']['ADE_15'], train_adult['MSE']['ADE_15'], train_elderly['MSE']['ADE_15'], train_all['MSE']['ADE_15']]
ax.boxplot(data);
ax.set_title('ADE(1.5) With Outliers');
ax.set_ylabel('MSE');
plt.xticks([1, 2, 3, 4], ['child', 'adult', 'elderly', 'all']);

fig, ax = plt.subplots(figsize = (10, 10))
ax.boxplot(data, showfliers = False);
ax.set_title('ADE(1.5) No Outliers');
ax.set_ylabel('MSE');
plt.xticks([1, 2, 3, 4], ['child', 'adult', 'elderly', 'all']);

# %% [markdown]
# #### C-ADE(1.5)

# %%
fig, ax = plt.subplots(figsize = (10, 10))
data = [train_child['MSE']['CADE'], train_adult['MSE']['CADE'], train_elderly['MSE']['CADE'], train_all['MSE']['ADE_15']]
ax.boxplot(data);
ax.set_title('C-ADE(1.5) With Outliers');
ax.set_ylabel('MSE');
plt.xticks([1, 2, 3, 4], ['child', 'adult', 'elderly', 'all']);

fig, ax = plt.subplots(figsize = (10, 10))
ax.boxplot(data, showfliers = False);
ax.set_title('C-ADE(1.5) No Outliers');
ax.set_ylabel('MSE');
plt.xticks([1, 2, 3, 4], ['child', 'adult', 'elderly', 'all']);

# %% [markdown]
# #### C-FDE(1.5)

# %%
fig, ax = plt.subplots(figsize = (10, 10))
data = [train_child['MSE']['CFADE'], train_adult['MSE']['CFADE'], train_elderly['MSE']['CFADE'], train_all['MSE']['CFADE']]
ax.boxplot(data);
ax.set_title('C_FDE(1.5) With Outliers');
ax.set_ylabel('MSE');
plt.xticks([1, 2, 3, 4], ['child', 'adult', 'elderly', 'all']);

fig, ax = plt.subplots(figsize = (10, 10))
ax.boxplot(data, showfliers = False);
ax.set_title('C_FDE(1.5) No Outliers');
ax.set_ylabel('MSE');
plt.xticks([1, 2, 3, 4], ['child', 'adult', 'elderly', 'all']);
